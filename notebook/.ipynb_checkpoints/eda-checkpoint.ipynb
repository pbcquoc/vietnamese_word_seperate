# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
train = pd.read_csv('../../data/word_seperate/corpus', header=None)

# %%
words = ' '.join(train[1].values.tolist()).split(' ')
counts = pd.value_counts(words)

# %%
counts.head(30).plot.bar()

# %%
chars = ''.join(train[0].values.tolist())
pd.value_counts(chars)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1b9fd440161c> in <module>()
# ----> 1 chars = ''.join(train[0].values.tolist())
#       2 pd.value_counts(chars)
#
# NameError: name 'train' is not defined
